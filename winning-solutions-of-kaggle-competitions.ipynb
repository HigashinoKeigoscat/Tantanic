# %% [markdown]
# ### Winning solutions of kaggle competitions: ###
#
# Generally at the end of every Kaggle competition, winners and other toppers used to share their solutions in the discussion forums. But it is a tedious task to search for the competitions and then for the solutions of these competitions when we need them. I always wanted to get the links to the solutions of all past Kaggle competitions at one place. I thought it would be a very good reference point many a times. Thanks to Kaggle team for the Meta Kaggle dataset, now I am able to get them in one single place through this notebook .
#
# Thanks a lot to [@sban](https://www.kaggle.com/shivamb) for this [wonderful kernel](https://www.kaggle.com/shivamb/data-science-glossary-on-kaggle/notebook) without which I wouldn't have got this notebook.
#
# I have inlcuded only "Featured" & "Research" competitions and the competitions are ordered based on recency. The solutions are ordered based on the number of upvotes received.
#
# Have fun and Happy Kaggling.!
#
# P.S : There are few outlier discussions (which are not actually solutions) too ;)
#
# In case if you find any of the solutions missing, please post them on the comments section with links. I will add them here.
#
# Thanks to notebook scheduler functionality by Kaggle, the script will automatically run once every month and update the results.

# %%
import numpy as np
import pandas as pd
from IPython.core.display import HTML

import warnings
warnings.filterwarnings("ignore")

data_path = "../input/"

competitions_df = pd.read_csv(data_path + "Competitions.csv")
comps_to_use = ["Featured", "Research", "Recruitment"]
competitions_df = competitions_df[competitions_df["HostSegmentTitle"].isin(comps_to_use)]
competitions_df["EnabledDate"] = pd.to_datetime(competitions_df["EnabledDate"], format="%m/%d/%Y %H:%M:%S")
competitions_df = competitions_df.sort_values(by="EnabledDate", ascending=False).reset_index(drop=True)
competitions_df.head()

forum_topics_df = pd.read_csv(data_path + "ForumTopics.csv")

comp_tags_df = pd.read_csv(data_path + "CompetitionTags.csv")
tags_df = pd.read_csv(data_path + "Tags.csv", usecols=["Id", "Name"])

def get_comp_tags(comp_id):
    temp_df = comp_tags_df[comp_tags_df["CompetitionId"]==comp_id]
    temp_df = pd.merge(temp_df, tags_df, left_on="TagId", right_on="Id")
    tags_str = "Tags : "
    for ind, row in temp_df.iterrows():
        tags_str += row["Name"] + ", "
    return tags_str.strip(", ")

def check_solution(topic):
    is_solution = False
    to_exclude = ["?", "submit", "why", "what", "resolution", "benchmark"]
    if "solution" in topic.lower():
        is_solution = True
        for exc in to_exclude:
            if exc in topic.lower():
                is_solution = False
    to_include = ["2nd place code", '"dance with ensemble" sharing']
    for inc in to_include:
        if inc in topic.lower():
            is_solution = True
    return is_solution

def get_discussion_results(forum_id, n):
    results_df = forum_topics_df[forum_topics_df["ForumId"]==forum_id]
    results_df["is_solution"] = results_df["Title"].apply(lambda x: check_solution(str(x)))
    results_df = results_df[results_df["is_solution"] == 1]
    results_df = results_df.sort_values(by=["Score","TotalMessages"], ascending=False).head(n).reset_index(drop=True)
    return results_df[["Title", "Id", "Score", "TotalMessages", "TotalReplies"]]

def render_html_for_comp(forum_id, comp_id, comp_name, comp_slug, comp_subtitle, n):
    results_df = get_discussion_results(forum_id, n)
    
    if len(results_df) < 1:
        return
    
    comp_tags = get_comp_tags(comp_id)
    
    comp_url = "https://www.kaggle.com/c/"+str(comp_slug)
    hs = """<style>
                .rendered_html tr {font-size: 12px; text-align: left;}
                th {
                text-align: left;
                }
            </style>
            <h3><font color="#1768ea"><a href="""+comp_url+""">"""+comp_name+"""</font></h3>
            <p>"""+comp_subtitle+"""</p>
            """
    
    if comp_tags != "Tags :":
        hs +=   """
            <p>"""+comp_tags+"""</p>
            """
    
    hs +=   """
            <table>
            <tr>
                <th><b>S.No</b></th>
                <th><b>Discussion Title</b></th>
                <th><b>Number of upvotes</b></th>
                <th><b>Total Replies</b></th>
            </tr>"""
    
    for i, row in results_df.iterrows():
        url = "https://www.kaggle.com/c/"+str(comp_slug)+"/discussion/"+str(row["Id"])
        hs += """<tr>
                    <td>"""+str(i+1)+"""</td>
                    <td><a href="""+url+""" target="_blank"><b>"""  +str(row['Title']) + """</b></a></td>
                    <td>"""+str(row['Score'])+"""</td>
                    <td>"""+str(row['TotalReplies'])+"""</td>
                    </tr>"""
    hs += "</table>"
    display(HTML(hs))

for ind, comp_row in competitions_df.iterrows():
    render_html_for_comp(comp_row["ForumId"], comp_row["Id"], comp_row["Title"], comp_row["Slug"], comp_row["Subtitle"], 12)
# Out:
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/santa-2022>Santa 2022 - The Christmas Card Conundrum</font></h3>
#             <p>Optimize the configuration space for printing an image</p>
#
#             <p>Tags : optimization, holidays and cultural events</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379086 target="_blank"><b>2nd place solution</b></a></td>
#                     <td>77</td>
#                     <td>21</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379080 target="_blank"><b>4th place solution</b></a></td>
#                     <td>69</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379167 target="_blank"><b>1st place solution with visualized route</b></a></td>
#                     <td>64</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379150 target="_blank"><b>9th place solution - with video visualization - Team Arm Breakers</b></a></td>
#                     <td>29</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379214 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>24</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379073 target="_blank"><b>Around 74450 86th place LKH TSP solution</b></a></td>
#                     <td>16</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/369644 target="_blank"><b>🌟 📓 Previous Year’s Top Solutions 🌟 📓</b></a></td>
#                     <td>15</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379132 target="_blank"><b>60th place solution (standard configuration + LKH)</b></a></td>
#                     <td>14</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379511 target="_blank"><b>8th place solution</b></a></td>
#                     <td>11</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379085 target="_blank"><b>74350 another TSP Solution with Pixel <-> Arm Configuration  64th Place</b></a></td>
#                     <td>11</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379249 target="_blank"><b>Best Score LKH-only solution</b></a></td>
#                     <td>5</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2022/discussion/379466 target="_blank"><b>Circular way to think about solution</b></a></td>
#                     <td>3</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves>G2Net Detecting Continuous Gravitational Waves</font></h3>
#             <p>Help us detect long-lasting gravitational-wave signals!</p>
#
#             <p>Tags : astronomy, signal processing</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375910 target="_blank"><b>1st place solution: Summing the power with GPU</b></a></td>
#                     <td>88</td>
#                     <td>37</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375897 target="_blank"><b>9th Place Solution; Simple CNN Approach</b></a></td>
#                     <td>46</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375923 target="_blank"><b>6th place solution (Simulated Annealing Approach)</b></a></td>
#                     <td>40</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/363280 target="_blank"><b>Recap of the Top Solutions from the Previous G2Net Competition</b></a></td>
#                     <td>35</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/376022 target="_blank"><b>5th place solution: Stack-sliding and Differential Evolution</b></a></td>
#                     <td>28</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375981 target="_blank"><b>11th place solution OR Simpler is Better</b></a></td>
#                     <td>26</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375961 target="_blank"><b>12th place solution - from public 281st to private 12th!</b></a></td>
#                     <td>22</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/376052 target="_blank"><b>10th place solution: CNN with pseudo labels</b></a></td>
#                     <td>18</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/376357 target="_blank"><b>4th place solution: dynamic programming and ensembling</b></a></td>
#                     <td>18</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/376504 target="_blank"><b>2nd Place Solution: GPU-Accelerated Random Search</b></a></td>
#                     <td>17</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/362869 target="_blank"><b>Winning Solutions of the Previous G2Net Competition (Gravitational Wave Detection)</b></a></td>
#                     <td>14</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/g2net-detecting-continuous-gravitational-waves/discussion/375927 target="_blank"><b>22th-place solution : simulated CW signals & augmentations</b></a></td>
#                     <td>12</td>
#                     <td>8</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction>Novozymes Enzyme Stability Prediction</font></h3>
#             <p>Help identify the thermostable mutations in enzymes</p>
#
#             <p>Tags : chemistry</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/376134 target="_blank"><b>2nd place solution & private LB 0.577 QUICK OVERVIEW</b></a></td>
#                     <td>47</td>
#                     <td>20</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/376147 target="_blank"><b>11th place solution</b></a></td>
#                     <td>36</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/376371 target="_blank"><b>1st place solution - Protein as a Graph</b></a></td>
#                     <td>34</td>
#                     <td>13</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/375900 target="_blank"><b>My incredibly lucky 6th place solution w code</b></a></td>
#                     <td>33</td>
#                     <td>23</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/376070 target="_blank"><b>8-th place solution - AVGP3 + Rosetta</b></a></td>
#                     <td>27</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/375964 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>26</td>
#                     <td>28</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/376163 target="_blank"><b>7-th place solution</b></a></td>
#                     <td>14</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/novozymes-enzyme-stability-prediction/discussion/375884 target="_blank"><b>Some thoughts on solutions and CV</b></a></td>
#                     <td>4</td>
#                     <td>9</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning>Feedback Prize - English Language Learning</font></h3>
#             <p>Evaluating language knowledge of ELL students from grades 8-12</p>
#
#             <p>Tags : education, nlp, primary and secondary schools</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369609 target="_blank"><b>3rd Place Solution - Congratulations New Competition Grandmaster Amed!</b></a></td>
#                     <td>108</td>
#                     <td>58</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369457 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>101</td>
#                     <td>56</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369369 target="_blank"><b>2nd solution (back-translation & rank-loss)</b></a></td>
#                     <td>97</td>
#                     <td>36</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/348967 target="_blank"><b>Top Solutions From Feedback 1 & 2</b></a></td>
#                     <td>83</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369578 target="_blank"><b>5th place solution</b></a></td>
#                     <td>63</td>
#                     <td>28</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/348957 target="_blank"><b>Winner Interviews and Solutions from Previous Feedback competitions</b></a></td>
#                     <td>55</td>
#                     <td>12</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369307 target="_blank"><b>[New Pilot] Winning Solution Write Up</b></a></td>
#                     <td>49</td>
#                     <td>25</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369567 target="_blank"><b>6th place solution</b></a></td>
#                     <td>43</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369368 target="_blank"><b>Single model  (avg 2 seeds) - gold solution</b></a></td>
#                     <td>42</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369440 target="_blank"><b>13th Place Solution</b></a></td>
#                     <td>41</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369524 target="_blank"><b>8th place solution</b></a></td>
#                     <td>33</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/feedback-prize-english-language-learning/discussion/369646 target="_blank"><b>Team Turing: Efficiency - 1st Place Solution</b></a></td>
#                     <td>31</td>
#                     <td>19</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/open-problems-multimodal>Open Problems - Multimodal Single-Cell Integration</font></h3>
#             <p>Predict how DNA, RNA & protein measurements co-vary in single cells</p>
#
#             <p>Tags : genetics, biotechnology, tabular</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/348792 target="_blank"><b>Recordings and Source codes of winners' solutions of this competition last year.</b></a></td>
#                     <td>96</td>
#                     <td>17</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366961 target="_blank"><b>1st Place Solution Summary</b></a></td>
#                     <td>95</td>
#                     <td>18</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366453 target="_blank"><b>2nd place solution(senkin part with code)</b></a></td>
#                     <td>90</td>
#                     <td>26</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366428 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>67</td>
#                     <td>18</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366471 target="_blank"><b>7th Place Solution Summary</b></a></td>
#                     <td>55</td>
#                     <td>12</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366455 target="_blank"><b>12th-Place Solution</b></a></td>
#                     <td>53</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366476 target="_blank"><b>2nd Place Solution  -  tmp's part ( code updated )</b></a></td>
#                     <td>41</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366417 target="_blank"><b>[6th private - 3rd public] Summary of our solution</b></a></td>
#                     <td>40</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366460 target="_blank"><b>4th place solution (with code)</b></a></td>
#                     <td>37</td>
#                     <td>17</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366409 target="_blank"><b>Private 5th Solution (A Beginner part)</b></a></td>
#                     <td>36</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/366372 target="_blank"><b>Private 41st Solution summary</b></a></td>
#                     <td>28</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/open-problems-multimodal/discussion/353225 target="_blank"><b>Ideas of winning solutions from the last year.</b></a></td>
#                     <td>27</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/ai-village-ctf>AI Village Capture the Flag @ DEFCON</font></h3>
#             <p>Hack AI! Collect flags by evading, poisoning, stealing, and fooling AI/ML</p>
#
#             <p>Tags : games, puzzles, adversarial learning</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351800 target="_blank"><b>7th Place - Published 21 Solutions in My Notebook</b></a></td>
#                     <td>32</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/353536 target="_blank"><b>1st place solution: A brief overview of my experience</b></a></td>
#                     <td>17</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/344845 target="_blank"><b>Reminder: Sharing answers/solutions is not permitted during the competition</b></a></td>
#                     <td>13</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351804 target="_blank"><b>Summary of 21 solutions (LB: 0.894)</b></a></td>
#                     <td>11</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351812 target="_blank"><b>Secret Sloth Solution</b></a></td>
#                     <td>10</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351863 target="_blank"><b>DeepFake Solution</b></a></td>
#                     <td>9</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/352622 target="_blank"><b>2nd Place Solution: The Solution Without Crop2</b></a></td>
#                     <td>8</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351808 target="_blank"><b>Looking forward to the crop2 solution from the hosts!</b></a></td>
#                     <td>7</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351866 target="_blank"><b>Henry Hacker's .984 solution</b></a></td>
#                     <td>6</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351850 target="_blank"><b>Crop1 Solutions by idx</b></a></td>
#                     <td>5</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/352765 target="_blank"><b>My solutions to all but crop2</b></a></td>
#                     <td>4</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/ai-village-ctf/discussion/351989 target="_blank"><b>Sloth solution(without the original image).</b></a></td>
#                     <td>4</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout>DFL - Bundesliga Data Shootout</font></h3>
#             <p>Identify plays based upon video footage</p>
#
#             <p>Tags : football, sports, video data</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360097 target="_blank"><b>2nd Place Solution</b></a></td>
#                     <td>127</td>
#                     <td>16</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/359932 target="_blank"><b>Team Hydrogen: 1st place solution</b></a></td>
#                     <td>114</td>
#                     <td>57</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360236 target="_blank"><b>public 3rd place solution</b></a></td>
#                     <td>71</td>
#                     <td>21</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360331 target="_blank"><b>Public 5th place solution</b></a></td>
#                     <td>37</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360573 target="_blank"><b>Public 4th place solution</b></a></td>
#                     <td>28</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/340636 target="_blank"><b>Similar competitions & solutions</b></a></td>
#                     <td>26</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360872 target="_blank"><b>A simple approach based on baseline notebooks (6th place solution)</b></a></td>
#                     <td>24</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/360418 target="_blank"><b>~570fps solution - Optimizing the speed of feeding the videos, another part of the challenge.</b></a></td>
#                     <td>9</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/374916 target="_blank"><b>7th place brief solution summary</b></a></td>
#                     <td>6</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/dfl-bundesliga-data-shootout/discussion/375615 target="_blank"><b>15th place short solution summary</b></a></td>
#                     <td>4</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection>RSNA 2022 Cervical Spine Fracture Detection</font></h3>
#             <p>Identify cervical fractures from scans</p>
#
#             <p>Tags : computer vision, image, binary classification</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362607 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>179</td>
#                     <td>86</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362787 target="_blank"><b>1st Place Solution -- Code</b></a></td>
#                     <td>102</td>
#                     <td>32</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362643 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>54</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362651 target="_blank"><b>[6th place] Solution Overview: 3D CNN + TD-CNN</b></a></td>
#                     <td>52</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/363232 target="_blank"><b>5th place solution (Team Speedrun)</b></a></td>
#                     <td>44</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362593 target="_blank"><b>32nd place solution</b></a></td>
#                     <td>42</td>
#                     <td>14</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362669 target="_blank"><b>8th Place Solution + Code</b></a></td>
#                     <td>42</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362640 target="_blank"><b>18th Place Solution</b></a></td>
#                     <td>34</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/365115 target="_blank"><b>2nd place solution ： Segmentation + 2.5D CNN + GRU Attention</b></a></td>
#                     <td>32</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362931 target="_blank"><b>17th place solution</b></a></td>
#                     <td>32</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/362687 target="_blank"><b>13th Place Solution</b></a></td>
#                     <td>31</td>
#                     <td>13</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-2022-cervical-spine-fracture-detection/discussion/364837 target="_blank"><b>4th place solution, CSN is all you need for 3D</b></a></td>
#                     <td>28</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/google-universal-image-embedding>Google Universal Image Embedding</font></h3>
#             <p>Create image representations that work across many visual domains</p>
#
#             <p>Tags : image, multiclass classification</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359316 target="_blank"><b>1st place solution</b></a></td>
#                     <td>145</td>
#                     <td>59</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359161 target="_blank"><b>5th place solution[NS embedding]</b></a></td>
#                     <td>62</td>
#                     <td>17</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359525 target="_blank"><b>[2nd place] Solution</b></a></td>
#                     <td>25</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359271 target="_blank"><b>10th Place Solution</b></a></td>
#                     <td>22</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359487 target="_blank"><b>GUIE 4th Place Solution</b></a></td>
#                     <td>21</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359351 target="_blank"><b>9th place solution: finetune CLIP ViT-H/14</b></a></td>
#                     <td>20</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/336716 target="_blank"><b>Similar Competition's (Shopee) Top Solution</b></a></td>
#                     <td>19</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359618 target="_blank"><b>28th Place Solution</b></a></td>
#                     <td>14</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359998 target="_blank"><b>LB 0.603 without data, a zero shot solution</b></a></td>
#                     <td>13</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359371 target="_blank"><b>Silver medal solution: ViT-L/14 with test time augmentations</b></a></td>
#                     <td>12</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/336618 target="_blank"><b>Previous Image recognition based competition solutions</b></a></td>
#                     <td>10</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/google-universal-image-embedding/discussion/359341 target="_blank"><b>13-th place solution [Knowledge Distillation helps a lot]</b></a></td>
#                     <td>9</td>
#                     <td>13</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai>Mayo Clinic - STRIP AI</font></h3>
#             <p>Image Classification of Stroke Blood Clot Origin</p>
#
#             <p>Tags : medicine, computer vision, classification, image</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/357892 target="_blank"><b>1st place solution</b></a></td>
#                     <td>61</td>
#                     <td>37</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/358029 target="_blank"><b>5th Place Solution</b></a></td>
#                     <td>31</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/358203 target="_blank"><b>13th Place Solution</b></a></td>
#                     <td>22</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/357898 target="_blank"><b>25th Solution - Custom MIL with timm backbones</b></a></td>
#                     <td>21</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/358089 target="_blank"><b>2nd place solution - EfficientNetB0+augmentations+smart tiling</b></a></td>
#                     <td>19</td>
#                     <td>14</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/336035 target="_blank"><b>Previous Image Classification competitions Solutions | Kaggle</b></a></td>
#                     <td>18</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/335706 target="_blank"><b>Winning solutions of previous image classification competitions</b></a></td>
#                     <td>16</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/358187 target="_blank"><b>3rd place solution - ResNet pretraining</b></a></td>
#                     <td>14</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/364466 target="_blank"><b>4th Place Solution - Split images into tiles and do 3D CNN</b></a></td>
#                     <td>13</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/358130 target="_blank"><b>7th place solution -> 2-step MIL based strategy</b></a></td>
#                     <td>13</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/mayo-clinic-strip-ai/discussion/359562 target="_blank"><b>6th place solution</b></a></td>
#                     <td>3</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/hubmap-organ-segmentation>HuBMAP + HPA - Hacking the Human Body</font></h3>
#             <p>Segment multi-organ functional tissue units</p>
#
#             <p>Tags : biology, computer vision, image</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354683 target="_blank"><b>3d  place solution</b></a></td>
#                     <td>63</td>
#                     <td>17</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/332664 target="_blank"><b>Previous HuBMAP - Solutions summary thread</b></a></td>
#                     <td>51</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354857 target="_blank"><b>2nd Place Solution</b></a></td>
#                     <td>48</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354851 target="_blank"><b>4th place solution: Stain Normalization is all you need</b></a></td>
#                     <td>42</td>
#                     <td>12</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/356201 target="_blank"><b>1st place solution</b></a></td>
#                     <td>36</td>
#                     <td>15</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354701 target="_blank"><b>11th place solution</b></a></td>
#                     <td>33</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354859 target="_blank"><b>7th place solution</b></a></td>
#                     <td>29</td>
#                     <td>12</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354744 target="_blank"><b>25th Simple Solution</b></a></td>
#                     <td>19</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/354671 target="_blank"><b>26th place solution | Recursive Gated Convolutions + Lung Tiling</b></a></td>
#                     <td>19</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/346949 target="_blank"><b>[Chai Time] Sanyam expains top solutions from medical CV competition RANZR CLiP</b></a></td>
#                     <td>8</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/355213 target="_blank"><b>27th Simple Solution</b></a></td>
#                     <td>8</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/hubmap-organ-segmentation/discussion/355509 target="_blank"><b>48th place solution</b></a></td>
#                     <td>6</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/amex-default-prediction>American Express - Default Prediction</font></h3>
#             <p>Predict if a customer will default in the future</p>
#
#             <p>Tags : finance, tabular, binary classification</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/348111 target="_blank"><b>1st solution(update github code)</b></a></td>
#                     <td>247</td>
#                     <td>106</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/347637 target="_blank"><b>2nd place solution - team JuneHomes (writeup)</b></a></td>
#                     <td>169</td>
#                     <td>56</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/347786 target="_blank"><b>11th Place Solution (LightGBM with meta features)</b></a></td>
#                     <td>102</td>
#                     <td>44</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/347668 target="_blank"><b>10th Place Solution: XGB with Autoregressive RNN features</b></a></td>
#                     <td>92</td>
#                     <td>29</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/348014 target="_blank"><b>13th Place Gold Solution</b></a></td>
#                     <td>75</td>
#                     <td>18</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/amex-default-prediction/discussion/349741 target="_blank"><b>3rd solution--simple is the best</b></a></td>
#                     <td>72</td>
# ...
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/kddcup2012-track2/discussion/2334 target="_blank"><b>Solution Posted</b></a></td>
#                     <td>1</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/kddcup2012-track1>KDD Cup 2012, Track 1</font></h3>
#             <p>Predict which users (or information sources) one user might follow in Tencent Weibo.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/kddcup2012-track1/discussion/2335 target="_blank"><b>Solution Posted</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/asap-aes>The Hewlett Foundation: Automated Essay Scoring</font></h3>
#             <p>Develop an automated scoring algorithm for student-written essays.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/asap-aes/discussion/229208 target="_blank"><b>optimal solution</b></a></td>
#                     <td>1</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/DontGetKicked>Don't Get Kicked!</font></h3>
#             <p>Predict if a car purchased at auction is a lemon</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/DontGetKicked/discussion/7524 target="_blank"><b>Solution</b></a></td>
#                     <td>1</td>
#                     <td>58</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/GiveMeSomeCredit>Give Me Some Credit</font></h3>
#             <p>Improve on the state of the art in credit scoring by predicting the probability that somebody will experience financial distress in the next two years.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/300684 target="_blank"><b>How i get the  Top 5 solution  :Give me Some Credit !!</b></a></td>
#                     <td>3</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/2788 target="_blank"><b>Winning solution(s)</b></a></td>
#                     <td>2</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/26536 target="_blank"><b>Automatic ML solution (6th place)</b></a></td>
#                     <td>1</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/dunnhumbychallenge>dunnhumby's Shopper Challenge</font></h3>
#             <p>Going grocery shopping, we all have to do it, some even enjoy it, but can you predict it? dunnhumby is looking to build a model to better predict when supermarket shoppers will next visit the store and how much they will spend.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/dunnhumbychallenge/discussion/749 target="_blank"><b>naive solution</b></a></td>
#                     <td>0</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/dunnhumbychallenge/discussion/762 target="_blank"><b>an example simple solution</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/mdm>Mapping Dark Matter</font></h3>
#             <p>Measure the small distortion in galaxy images caused by dark matter</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/605 target="_blank"><b>mdm_training_solution.csv file</b></a></td>
#                     <td>0</td>
#                     <td>27</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/796 target="_blank"><b>Solution</b></a></td>
#                     <td>0</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/614 target="_blank"><b>Updated training solution and rescore</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/hhp>Heritage Health Prize</font></h3>
#             <p>Identify patients who will be admitted to a hospital within the next year using historical claims data. (Enter by 06:59:59 UTC Oct 4 2012)</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/409 target="_blank"><b>Evaluation Metric Issues: Solutions where 100% of patients went to hospital could have higher score!</b></a></td>
#                     <td>0</td>
#                     <td>36</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/390 target="_blank"><b>Solution idea for limited data problems, reidentification attacks</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/1272 target="_blank"><b>First Milestone Solution</b></a></td>
#                     <td>0</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/ChessRatings2>Deloitte/FIDE Chess Rating Challenge</font></h3>
#             <p>This contest, sponsored by professional services firm Deloitte, will find the most accurate system to predict chess outcomes, and FIDE will also bring a top finisher to Athens to present their system</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/ChessRatings2/discussion/575 target="_blank"><b>Follow-up Solution Set</b></a></td>
#                     <td>0</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/ChessRatings2/discussion/505 target="_blank"><b>Test Solution File</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/stayalert>Stay Alert! The Ford Challenge</font></h3>
#             <p>Driving while not alert can be deadly. The objective is to design a classifier that will detect whether the driver is alert or not alert, employing data that are acquired while driving.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/stayalert/discussion/279 target="_blank"><b>Solutions</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/stayalert/discussion/280 target="_blank"><b>Solutions</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/unimelb>Predict Grant Applications</font></h3>
#             <p>This task requires participants to predict the outcome of grant applications for the University of Melbourne.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/unimelb/discussion/302 target="_blank"><b>Solution</b></a></td>
#                     <td>10</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/unimelb/discussion/21894 target="_blank"><b>Trying to check a submission: "This competition does not have a solution to test a submission against"</b></a></td>
#                     <td>3</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/RTA>RTA Freeway Travel Time Prediction</font></h3>
#             <p>This competition requires participants to predict travel time on Sydney's M4 freeway from past travel time observations.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/RTA/discussion/294 target="_blank"><b>Solution</b></a></td>
#                     <td>1</td>
#                     <td>10</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/worldcupconf>World Cup 2010 - Confidence Challenge</font></h3>
#             <p>The Confidence Challenge requires competitors to assign a level of confidence to their World Cup predictions.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/worldcupconf/discussion/73 target="_blank"><b>Solution file</b></a></td>
#                     <td>1</td>
#                     <td>5</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/hivprogression>Predict HIV Progression</font></h3>
#             <p>This contest requires competitors to predict the likelihood that an HIV patient's infection will become less severe, given a small dataset and limited clinical information.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/hivprogression/discussion/46 target="_blank"><b>The solution</b></a></td>
#                     <td>0</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/hivprogression/discussion/119608 target="_blank"><b>Submissions Closed/Solution Data Unavailable</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr></table>
